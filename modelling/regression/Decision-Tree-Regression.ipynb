# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/khetansarvesh/Tabular-Cross-Sectional-Modelling/blob/main/modelling/regression/Decision-Tree-Regression.ipynb)

# %% [markdown]
# # **DECISION TREE REGRESSION**
#
#
# 1.   Is also called Decision Tree Regressor or Regression Tree
# 2.   This is a non-linear regression algorithm
# 3.   It can be used for both 1 independent feature and more than 1 independent feature
# 4.   Decision tree has low bias and high variance as stated in the video but it is converted into low bias and low variance using pruning technique as shown in the video.This is taken care by the algorithm itself.This pruning thing is also called hyper parameter tuning of decision tree
