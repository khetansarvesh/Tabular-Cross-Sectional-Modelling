# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/khetansarvesh/Tabular-Cross-Sectional-Modelling/blob/main/modelling/recommendation_systems/AutoEncoders.ipynb)

# %% [markdown]
# to create a recommendation engine to predict the rating that a user will give for a movies between 1 to 5 ( 1 means he did not like the movie while 5 means he liked the movie very much)

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.utils.data
from torch.autograd import Variable

# %%
# !git clone https://github.com/khetansarvesh/Tabular-Cross-Sectional-Modelling.git
# Out:
# Cloning into 'Tabular-Cross-Sectional-Modelling'...
# remote: Enumerating objects: 528, done.
# remote: Counting objects: 100% (265/265), done.
# remote: Compressing objects: 100% (224/224), done.
# remote: Total 528 (delta 184), reused 72 (delta 41), pack-reused 263
# Receiving objects: 100% (528/528), 10.98 MiB | 14.01 MiB/s, done.
# Resolving deltas: 100% (313/313), done.

# %%
# %cd Tabular-Cross-Sectional-Modelling/dataset/movie_rating_dataset
# Out:
# /content/Tabular-Cross-Sectional-Modelling/dataset/movie_rating_dataset/Tabular-Cross-Sectional-Modelling/dataset/movie_rating_dataset

# %% [markdown]
# # **Dataset**

# %%
# train dataset
train_df = pd.read_csv('train_df.csv')
train_set = np.array(train_df)
training_set = torch.FloatTensor(train_set)

# %%
# test dataset
test_df = pd.read_csv('test_df.csv')
test_set = np.array(test_df)
test_set = torch.FloatTensor(test_set)

# %%
nb_users = train_df.shape[0]
nb_movies = train_df.shape[1]

# %% [markdown]
# # **Modelling**

# %%
class SAE(nn.Module):

    def __init__(self, ):
        super(SAE, self).__init__()
        self.fc1 = nn.Linear(nb_movies, 20)
        self.fc2 = nn.Linear(20, 10)
        self.fc3 = nn.Linear(10, 20)
        self.fc4 = nn.Linear(20, nb_movies)
        self.activation = nn.Sigmoid()

    def forward(self, x):
        x = self.activation(self.fc1(x))
        x = self.activation(self.fc2(x))
        x = self.activation(self.fc3(x))
        x = self.fc4(x)
        return x

# %% [markdown]
# # **Training**

# %%
sae = SAE()
criterion = nn.MSELoss()
optimizer = optim.RMSprop(sae.parameters(), lr = 0.01, weight_decay = 0.5)

# %%
nb_epoch = 200
for epoch in range(1, nb_epoch + 1):
  train_loss = 0
  s = 0.
  for id_user in range(nb_users):
    input = Variable(training_set[id_user]).unsqueeze(0)
    target = input.clone()
    if torch.sum(target.data > 0) > 0:
      output = sae(input)
      target.require_grad = False
      output[target == 0] = 0
      loss = criterion(output, target)
      mean_corrector = nb_movies/float(torch.sum(target.data > 0) + 1e-10)
      loss.backward()
      train_loss += np.sqrt(loss.data*mean_corrector)
      s += 1.
      optimizer.step()
  print('epoch: '+str(epoch)+'loss: '+ str(train_loss/s))
# Out:
# epoch: 1loss: tensor(37.9259)
# epoch: 2loss: tensor(27.7981)
# epoch: 3loss: tensor(39.6664)
# epoch: 4loss: tensor(60.9344)
# epoch: 5loss: tensor(57.1118)
# epoch: 6loss: tensor(55.8065)
# epoch: 7loss: tensor(54.5778)
# epoch: 8loss: tensor(53.4027)
# epoch: 9loss: tensor(52.2731)
# epoch: 10loss: tensor(51.1808)
# epoch: 11loss: tensor(50.1242)
# epoch: 12loss: tensor(49.1076)
# epoch: 13loss: tensor(48.1262)
# epoch: 14loss: tensor(47.1807)
# epoch: 15loss: tensor(46.2780)
# epoch: 16loss: tensor(45.4156)
# epoch: 17loss: tensor(44.5909)
# epoch: 18loss: tensor(43.8051)
# epoch: 19loss: tensor(43.0571)
# epoch: 20loss: tensor(42.3396)
# epoch: 21loss: tensor(41.6539)
# epoch: 22loss: tensor(41.0018)
# epoch: 23loss: tensor(40.3857)
# epoch: 24loss: tensor(39.8036)
# epoch: 25loss: tensor(39.2559)
# epoch: 26loss: tensor(38.7452)
# epoch: 27loss: tensor(38.2678)
# epoch: 28loss: tensor(37.8246)
# epoch: 29loss: tensor(37.4105)
# epoch: 30loss: tensor(37.0288)
# epoch: 31loss: tensor(36.6786)
# epoch: 32loss: tensor(36.3530)
# epoch: 33loss: tensor(36.0606)
# epoch: 34loss: tensor(35.7985)
# epoch: 35loss: tensor(35.5623)
# epoch: 36loss: tensor(35.3544)
# epoch: 37loss: tensor(35.1729)
# epoch: 38loss: tensor(35.0231)
# epoch: 39loss: tensor(34.9067)
# epoch: 40loss: tensor(34.8211)
# epoch: 41loss: tensor(34.7619)
# epoch: 42loss: tensor(34.7258)
# epoch: 43loss: tensor(34.7130)
# epoch: 44loss: tensor(34.7283)
# epoch: 45loss: tensor(34.7707)
# epoch: 46loss: tensor(34.8386)
# epoch: 47loss: tensor(34.9332)
# epoch: 48loss: tensor(35.0487)
# epoch: 49loss: tensor(35.1843)
# epoch: 50loss: tensor(35.3440)
# epoch: 51loss: tensor(35.5280)
# epoch: 52loss: tensor(35.7335)
# epoch: 53loss: tensor(35.9578)
# epoch: 54loss: tensor(36.2049)
# epoch: 55loss: tensor(36.4808)
# epoch: 56loss: tensor(36.7800)
# epoch: 57loss: tensor(37.0987)
# epoch: 58loss: tensor(37.4397)
# epoch: 59loss: tensor(37.8052)
# epoch: 60loss: tensor(38.1961)
# epoch: 61loss: tensor(38.6164)
# epoch: 62loss: tensor(39.0630)
# epoch: 63loss: tensor(39.5343)
# epoch: 64loss: tensor(40.0320)
# epoch: 65loss: tensor(40.5553)
# epoch: 66loss: tensor(41.0996)
# epoch: 67loss: tensor(41.6671)
# epoch: 68loss: tensor(42.2571)
# epoch: 69loss: tensor(42.8709)
# epoch: 70loss: tensor(43.5065)
# epoch: 71loss: tensor(44.1652)
# epoch: 72loss: tensor(44.8511)
# epoch: 73loss: tensor(45.5648)
# epoch: 74loss: tensor(46.3036)
# epoch: 75loss: tensor(47.0651)
# epoch: 76loss: tensor(47.8488)
# epoch: 77loss: tensor(48.6608)
# epoch: 78loss: tensor(49.5004)
# epoch: 79loss: tensor(50.3665)
# epoch: 80loss: tensor(51.2549)
# epoch: 81loss: tensor(52.1671)
# epoch: 82loss: tensor(53.1034)
# epoch: 83loss: tensor(54.0643)
# epoch: 84loss: tensor(55.0501)
# epoch: 85loss: tensor(56.0606)
# epoch: 86loss: tensor(57.0987)
# epoch: 87loss: tensor(58.1664)
# epoch: 88loss: tensor(59.2572)
# epoch: 89loss: tensor(60.3681)
# epoch: 90loss: tensor(61.4983)
# epoch: 91loss: tensor(62.6504)
# epoch: 92loss: tensor(63.8155)
# epoch: 93loss: tensor(64.9887)
# epoch: 94loss: tensor(66.1430)
# epoch: 95loss: tensor(66.9070)
# epoch: 96loss: tensor(65.7310)
# epoch: 97loss: tensor(64.4198)
# epoch: 98loss: tensor(63.1809)
# epoch: 99loss: tensor(61.9855)
# epoch: 100loss: tensor(60.8245)
# epoch: 101loss: tensor(59.6918)
# epoch: 102loss: tensor(58.5871)
# epoch: 103loss: tensor(57.5149)
# epoch: 104loss: tensor(56.4759)
# epoch: 105loss: tensor(55.4646)
# epoch: 106loss: tensor(54.4804)
# epoch: 107loss: tensor(53.5227)
# epoch: 108loss: tensor(52.5899)
# epoch: 109loss: tensor(51.6827)
# epoch: 110loss: tensor(50.7990)
# epoch: 111loss: tensor(49.9409)
# epoch: 112loss: tensor(49.1116)
# epoch: 113loss: tensor(48.3118)
# epoch: 114loss: tensor(47.5366)
# epoch: 115loss: tensor(46.7825)
# epoch: 116loss: tensor(46.0536)
# epoch: 117loss: tensor(45.3511)
# epoch: 118loss: tensor(44.6765)
# epoch: 119loss: tensor(44.0274)
# epoch: 120loss: tensor(43.3996)
# epoch: 121loss: tensor(42.7950)
# epoch: 122loss: tensor(42.2133)
# epoch: 123loss: tensor(41.6550)
# epoch: 124loss: tensor(41.1177)
# epoch: 125loss: tensor(40.6039)
# epoch: 126loss: tensor(40.1155)
# epoch: 127loss: tensor(39.6537)
# epoch: 128loss: tensor(39.2158)
# epoch: 129loss: tensor(38.8061)
# epoch: 130loss: tensor(38.4243)
# epoch: 131loss: tensor(38.0668)
# epoch: 132loss: tensor(37.7335)
# epoch: 133loss: tensor(37.4204)
# epoch: 134loss: tensor(37.1272)
# epoch: 135loss: tensor(36.8586)
# epoch: 136loss: tensor(36.6188)
# epoch: 137loss: tensor(36.3989)
# epoch: 138loss: tensor(36.1977)
# epoch: 139loss: tensor(36.0185)
# epoch: 140loss: tensor(35.8634)
# epoch: 141loss: tensor(35.7316)
# epoch: 142loss: tensor(35.6183)
# epoch: 143loss: tensor(35.5268)
# epoch: 144loss: tensor(35.4618)
# epoch: 145loss: tensor(35.4215)
# epoch: 146loss: tensor(35.4084)
# epoch: 147loss: tensor(35.4222)
# epoch: 148loss: tensor(35.4586)
# epoch: 149loss: tensor(35.5173)
# epoch: 150loss: tensor(35.6018)
# epoch: 151loss: tensor(35.7162)
# epoch: 152loss: tensor(35.8628)
# epoch: 153loss: tensor(36.0415)
# epoch: 154loss: tensor(36.2457)
# epoch: 155loss: tensor(36.4775)
# epoch: 156loss: tensor(36.7336)
# epoch: 157loss: tensor(37.0187)
# epoch: 158loss: tensor(37.3365)
# epoch: 159loss: tensor(37.6796)
# epoch: 160loss: tensor(38.0504)
# epoch: 161loss: tensor(38.4537)
# epoch: 162loss: tensor(38.8840)
# epoch: 163loss: tensor(39.3469)
# epoch: 164loss: tensor(39.8413)
# epoch: 165loss: tensor(40.3713)
# epoch: 166loss: tensor(40.9343)
# epoch: 167loss: tensor(41.5304)
# epoch: 168loss: tensor(42.1584)
# epoch: 169loss: tensor(42.8207)
# epoch: 170loss: tensor(43.5121)
# epoch: 171loss: tensor(44.2333)
# epoch: 172loss: tensor(44.9838)
# epoch: 173loss: tensor(45.7718)
# epoch: 174loss: tensor(46.5932)
# epoch: 175loss: tensor(47.4485)
# epoch: 176loss: tensor(48.3410)
# epoch: 177loss: tensor(49.2694)
# epoch: 178loss: tensor(50.2257)
# epoch: 179loss: tensor(51.2094)
# epoch: 180loss: tensor(52.2181)
# epoch: 181loss: tensor(53.2392)
# epoch: 182loss: tensor(54.2486)
# epoch: 183loss: tensor(54.8013)
# epoch: 184loss: tensor(53.6477)
# epoch: 185loss: tensor(52.4639)
# epoch: 186loss: tensor(51.3473)
# epoch: 187loss: tensor(50.2745)
# epoch: 188loss: tensor(49.2445)
# epoch: 189loss: tensor(48.2539)
# epoch: 190loss: tensor(47.2998)
# epoch: 191loss: tensor(46.3895)
# epoch: 192loss: tensor(45.5209)
# epoch: 193loss: tensor(44.6903)
# epoch: 194loss: tensor(43.8981)
# epoch: 195loss: tensor(43.1453)
# epoch: 196loss: tensor(42.4230)
# epoch: 197loss: tensor(41.7337)
# epoch: 198loss: tensor(41.0763)
# epoch: 199loss: tensor(40.4553)
# epoch: 200loss: tensor(39.8681)

# %% [markdown]
# # **Inference**

# %%
test_loss = 0
s = 0.
for id_user in range(nb_users):
  input = Variable(training_set[id_user]).unsqueeze(0)
  target = Variable(test_set[id_user]).unsqueeze(0)
  if torch.sum(target.data > 0) > 0:
    output = sae(input)
    target.require_grad = False
    output[target == 0] = 0
    loss = criterion(output, target)
    mean_corrector = nb_movies/float(torch.sum(target.data > 0) + 1e-10)
    test_loss += np.sqrt(loss.data*mean_corrector)
    s += 1.
print('test loss: '+str(test_loss/s))
# Out:
# test loss: tensor(252.1464)
